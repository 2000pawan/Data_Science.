# %% [markdown]
# # Fashion-MNIST is a dataset of Zolando's article image consisting of a traning set of 60,000 images and a test of 10,000 images. Each image is a 28*28 grayscale image, associated with a label from 10- classes.
#
# # Labels:-
# # Each Training and testing example is assigned to one of the following labels:-
# # 0 T-Shirt/Top
# # 1 Trouser
# # 2 Pullover
# # 3 Dress
# # 4 Coat
# # 5 Sandal
# # 6 Shirt
# # 7 Sneaker
# # 8 Bag
# # 9 Ankel Boot
# # For Further assistance https://www.kaggle.com/zolando-research/fashionmnist

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D
from tensorflow.keras.models import Sequential
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#loading data
(train_x,train_y),(test_x,test_y)=fashion_mnist.load_data()

# %%
train_x.shape
test_x.shape
# Out:
# (10000, 28, 28)

# %%
for i in range(9):
  plt.subplot(3,3,1+i)
  plt.imshow(train_x[i],cmap=plt.get_cmap('gray'))
plt.show()

# %%
for i in range(9):
  plt.subplot(3,3,1+i)
  plt.imshow(train_x[i])
plt.show()

# %%
#Feature Scaling
x_train=train_x/255
x_test=test_x/255

# %%
model=Sequential()
model.add(Conv2D(64,(3,3,),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3,),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit( x_train,train_y,epochs=10,batch_size=64)
loss,accuracy=model.evaluate(x_test,test_y)
print('Test Loss',loss)
print('Test Accuracy',accuracy)
# Out:
# Epoch 1/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.7496 - loss: 0.7078
# Epoch 2/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8759 - loss: 0.3413
# Epoch 3/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8960 - loss: 0.2846
# Epoch 4/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9108 - loss: 0.2464
# Epoch 5/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9177 - loss: 0.2258
# Epoch 6/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9250 - loss: 0.2023
# Epoch 7/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.9324 - loss: 0.1821
# Epoch 8/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9371 - loss: 0.1697
# Epoch 9/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9440 - loss: 0.1534
# Epoch 10/10
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9494 - loss: 0.1382
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9052 - loss: 0.2857
# Test Loss 0.28336721658706665
# Test Accuracy 0.9052000045776367

# %%
#single predictions in number category
prdictions=model.predict(x_test)
print(np.argmax(prdictions[0]))
print(test_y[0])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 9
# 9

# %%
model=Sequential()
model.add(Conv2D(64,(3,3,),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64,(3,3,),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.fit( x_train,train_y,epochs=30,batch_size=64)
loss,accuracy=model.evaluate(x_test,test_y)
print('Test Loss',loss)
print('Test Accuracy',accuracy)
# Out:
# Epoch 1/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.7339 - loss: 0.7470
# Epoch 2/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8769 - loss: 0.3450
# Epoch 3/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.8935 - loss: 0.2905
# Epoch 4/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9033 - loss: 0.2598
# Epoch 5/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9153 - loss: 0.2326
# Epoch 6/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9218 - loss: 0.2115
# Epoch 7/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9266 - loss: 0.1997
# Epoch 8/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9363 - loss: 0.1770
# Epoch 9/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9388 - loss: 0.1649
# Epoch 10/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9436 - loss: 0.1483
# Epoch 11/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9504 - loss: 0.1369
# Epoch 12/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9537 - loss: 0.1247
# Epoch 13/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9555 - loss: 0.1194
# Epoch 14/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9619 - loss: 0.1059
# Epoch 15/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9645 - loss: 0.0965
# Epoch 16/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9686 - loss: 0.0872
# Epoch 17/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9695 - loss: 0.0817
# Epoch 18/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9717 - loss: 0.0775
# Epoch 19/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9723 - loss: 0.0724
# Epoch 20/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9762 - loss: 0.0639
# Epoch 21/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9783 - loss: 0.0588
# Epoch 22/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9788 - loss: 0.0561
# Epoch 23/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9822 - loss: 0.0495
# Epoch 24/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9829 - loss: 0.0469
# Epoch 25/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9834 - loss: 0.0464
# Epoch 26/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9855 - loss: 0.0405
# Epoch 27/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9859 - loss: 0.0384
# Epoch 28/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9869 - loss: 0.0360
# Epoch 29/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9877 - loss: 0.0345
# Epoch 30/30
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9866 - loss: 0.0355
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9054 - loss: 0.5460
# Test Loss 0.513849675655365
# Test Accuracy 0.9057000279426575

# %%
#single predictions in number category
prdictions=model.predict(x_test)
print(np.argmax(prdictions[5000]))
print(test_y[5000])
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 2
# 2

# %%
plt.imshow(test_x[5000].reshape(28,28))
plt.show()
