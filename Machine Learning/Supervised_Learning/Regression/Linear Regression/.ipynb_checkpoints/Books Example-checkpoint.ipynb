# %% [markdown]
# # Home Price Data

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import r2_score

# %%
df=pd.read_csv("G:/dataset/MLbookdataset/Machine-Learning-Datasets-Updated (1)/Machine Learning Datasets Updated/19. Simple Linear Regression/homeprices.csv")
print(df)
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
sn.scatterplot(data=df,x='area',y='price')
plt.show()
model=LinearRegression()
model.fit(X,y)
print('Coefficient:-',model.coef_)
print('Intercept:-',model.intercept_)
print(model.predict([[3300]]))
y_predict=model.predict(X)
print('Accuracy Score r2_score:- ',r2_score(y,y_predict))
sn.lmplot(data=df,x='area',y='price')
plt.show()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000
# Coefficient:- [135.78767123]
# Intercept:- 180616.43835616432
# [628715.75342466]
# Accuracy Score r2_score:-  0.9584301138199486

# %%
# y=mx+c
y=133.78767123*3300+180616.43835616432
y
# Out:
# 622115.7534151643

# %% [markdown]
# # Salary Data

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("G:/dataset/MLbookdataset/Machine-Learning-Datasets-Updated (1)/Machine Learning Datasets Updated/19. Simple Linear Regression/Salary_Data.csv")
print(df)
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
plt.scatter(X,y,color='red')
plt.show()
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=10)
model=LinearRegression()
model.fit(X_train,y_train)
y_predict=model.predict(X_train)
y_predict_test=model.predict(X_test)
print('Accuracy Score r2_score Train Sample:- ',r2_score(y_train,y_predict))
print('Accuracy Score r2_score Test Sample:- ',r2_score(y_test,y_predict_test))
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,y_predict,color='blue')
plt.title('Experience VS Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872
# Accuracy Score r2_score Train Sample:-  0.9487492719684325
# Accuracy Score r2_score Test Sample:-  0.9760442172946989

# %%
print(model.predict([[eval(input())]]))
# Out:
#  9.6
# [116459.31322211]

# %% [markdown]
# # Canada Per Capita Income

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
df=pd.read_excel("G:/dataset/MLbookdataset/Machine-Learning-Datasets-Updated (1)/Machine Learning Datasets Updated/19. Simple Linear Regression/canada_per_capita_income.xlsx")
print(df)
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values
plt.scatter(X,y,color='red')
plt.show()
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=5)
model=LinearRegression()
model.fit(X_train,y_train)
y_predict=model.predict(X_train)
y_predict_test=model.predict(X_test)
print('Accuracy Score r2_score Train Sample:- ',r2_score(y_train,y_predict))
print('Accuracy Score r2_score Test Sample:- ',r2_score(y_test,y_predict_test))
plt.scatter(X_train,y_train,color='red')
plt.plot(X_train,y_predict,color='blue')
plt.title('Experience VS Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
# Out:
#     year        income
# 0   1970   3399.299037
# 1   1971   3768.297935
# 2   1972   4251.175484
# 3   1973   4804.463248
# 4   1974   5576.514583
# 5   1975   5998.144346
# 6   1976   7062.131392
# 7   1977   7100.126170
# 8   1978   7247.967035
# 9   1979   7602.912681
# 10  1980   8355.968120
# 11  1981   9434.390652
# 12  1982   9619.438377
# 13  1983  10416.536590
# 14  1984  10790.328720
# 15  1985  11018.955850
# 16  1986  11482.891530
# 17  1987  12974.806620
# 18  1988  15080.283450
# 19  1989  16426.725480
# 20  1990  16838.673200
# 21  1991  17266.097690
# 22  1992  16412.083090
# 23  1993  15875.586730
# 24  1994  15755.820270
# 25  1995  16369.317250
# 26  1996  16699.826680
# 27  1997  17310.757750
# 28  1998  16622.671870
# 29  1999  17581.024140
# 30  2000  18987.382410
# 31  2001  18601.397240
# 32  2002  19232.175560
# 33  2003  22739.426280
# 34  2004  25719.147150
# 35  2005  29198.055690
# 36  2006  32738.262900
# 37  2007  36144.481220
# 38  2008  37446.486090
# 39  2009  32755.176820
# 40  2010  38420.522890
# 41  2011  42334.711210
# 42  2012  42665.255970
# 43  2013  42676.468370
# 44  2014  41039.893600
# 45  2015  35175.188980
# 46  2016  34229.193630
# Accuracy Score r2_score Train Sample:-  0.8977842490653634
# Accuracy Score r2_score Test Sample:-  0.8433026110551844

# %%
model.predict([[2020],[2021]])
# Out:
# array([41819.49650873, 42681.02869595])
