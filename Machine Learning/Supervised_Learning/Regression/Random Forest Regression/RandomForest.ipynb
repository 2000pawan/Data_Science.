# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# # Salary Experience

# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/31. Random Forest/Salary_Experience.csv')
X=df.iloc[:,0:1].values
y=df.iloc[:,-1].values
model=RandomForestRegressor(n_estimators=100,random_state=0)
model.fit(X,y)
print('Accuracy Score of model:- ',model.score(X,y))
plt.scatter(X,y,color='blue')
plt.plot(X,model.predict(X),color='red')
plt.title('Random Forest Regression')
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.show()
# Out:
# Accuracy Score of model:-  0.9923669456643155

# %%
model.predict([[4.2],[7]])
# Out:
# array([56932.77516667, 98687.5       ])
