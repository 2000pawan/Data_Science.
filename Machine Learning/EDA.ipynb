# %% [markdown]
# # EDA(Exploratory Data Analysis)

# %% [markdown]
# # Cars Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Knowing Initial Details about Data

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/cars.csv')
df.shape
# Out:
# (429, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         429 non-null    object
#  1   Model        429 non-null    object
#  2   Type         429 non-null    object
#  3   Origin       429 non-null    object
#  4   DriveTrain   429 non-null    object
#  5   MSRP         429 non-null    object
#  6   Invoice      429 non-null    object
#  7   EngineSize   429 non-null    float64
#  8   Cylinders    427 non-null    float64
#  9   Horsepower   429 non-null    int64
#  10  MPG_City     429 non-null    int64
#  11  MPG_Highway  429 non-null    int64
#  12  Weight       429 non-null    int64
#  13  Wheelbase    429 non-null    int64
#  14  Length       429 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.4+ KB

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'], dtype=object)

# %%
print(list(df.columns))
# Out:
# ['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice', 'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway', 'Weight', 'Wheelbase', 'Length']

# %%
df.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172

# %%
df.tail(2)
# Out:
#       Make Model   Type  Origin DriveTrain      MSRP   Invoice  EngineSize  \
# 427  Volvo  XC70  Wagon  Europe        All  $35,145   $33,112          2.5
# 428  Volvo  XC70  Wagon  Europe        All  $35,145   $33,112          2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 427        5.0         208        20           27    3823        109     186
# 428        5.0         208        20           27    3823        109     186

# %%
df.head(4)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186

# %%
df.tail(4)
# Out:
#       Make       Model   Type  Origin DriveTrain      MSRP   Invoice  \
# 425  Volvo  S80 T6 4dr  Sedan  Europe      Front  $45,210   $42,573
# 426  Volvo         V40  Wagon  Europe      Front  $26,135   $24,641
# 427  Volvo        XC70  Wagon  Europe        All  $35,145   $33,112
# 428  Volvo        XC70  Wagon  Europe        All  $35,145   $33,112
#
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 425         2.9        6.0         268        19           26    3653
# 426         1.9        4.0         170        22           29    2822
# 427         2.5        5.0         208        20           27    3823
# 428         2.5        5.0         208        20           27    3823
#
#      Wheelbase  Length
# 425        110     190
# 426        101     180
# 427        109     186
# 428        109     186

# %% [markdown]
# # Modifying or Removing Unwanted Data

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/cars.csv')
df.drop(['MSRP','Invoice'],axis=1)
# Out:
#       Make                    Model   Type  Origin DriveTrain  EngineSize  \
# 0    Acura                      MDX    SUV    Asia        All         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 3    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 426  Volvo                      V40  Wagon  Europe      Front         1.9
# 427  Volvo                     XC70  Wagon  Europe        All         2.5
# 428  Volvo                     XC70  Wagon  Europe        All         2.5
#
#      Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 0          6.0         265        17           23    4451        106     189
# 1          4.0         200        24           31    2778        101     172
# 2          4.0         200        22           29    3230        105     183
# 3          6.0         270        20           28    3575        108     186
# 4          6.0         225        18           24    3880        115     197
# ..         ...         ...       ...          ...     ...        ...     ...
# 424        5.0         242        20           26    3450        105     186
# 425        6.0         268        19           26    3653        110     190
# 426        4.0         170        22           29    2822        101     180
# 427        5.0         208        20           27    3823        109     186
# 428        5.0         208        20           27    3823        109     186
#
# [429 rows x 13 columns]

# %%
df.drop_duplicates(keep='first')
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        17           23
# 1    $21,761          2.0        4.0         200        24           31
# 2    $24,647          2.4        4.0         200        22           29
# 3    $30,299          3.2        6.0         270        20           28
# 4    $39,014          3.5        6.0         225        18           24
# ..        ...         ...        ...         ...       ...          ...
# 423  $38,203          2.4        5.0         197        21           28
# 424  $40,083          2.3        5.0         242        20           26
# 425  $42,573          2.9        6.0         268        19           26
# 426  $24,641          1.9        4.0         170        22           29
# 427  $33,112          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 0      4451        106     189
# 1      2778        101     172
# 2      3230        105     183
# 3      3575        108     186
# 4      3880        115     197
# ..      ...        ...     ...
# 423    3450        105     186
# 424    3450        105     186
# 425    3653        110     190
# 426    2822        101     180
# 427    3823        109     186
#
# [428 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df1=df.sort_values(by='MPG_City',ascending=False)
df1
# Out:
#            Make                                   Model    Type  Origin  \
# 150       Honda              Insight 2dr (gas/electric)  Hybrid    Asia
# 373      Toyota                Prius 4dr (gas/electric)  Hybrid    Asia
# 149       Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid    Asia
# 404  Volkswagen                       Jetta GLS TDI 4dr   Sedan  Europe
# 155       Honda                            Civic HX 2dr   Sedan    Asia
# ..          ...                                     ...     ...     ...
# 216  Land Rover                            Discovery SE     SUV  Europe
# 215  Land Rover                         Range Rover HSE     SUV  Europe
# 114       Dodge            Viper SRT-10 convertible 2dr  Sports     USA
# 166      Hummer                                      H2     SUV     USA
# 118        Ford                       Excursion 6.8 XLT     SUV     USA
#
#     DriveTrain      MSRP   Invoice  EngineSize  Cylinders  Horsepower  \
# 150      Front  $19,110   $17,911          2.0        3.0          73
# 373      Front  $20,510   $18,926          1.5        4.0         110
# 149      Front  $20,140   $18,451          1.4        4.0          93
# 404      Front  $21,055   $19,638          1.9        4.0         100
# 155      Front  $14,170   $12,996          1.7        4.0         117
# ..         ...       ...       ...         ...        ...         ...
# 216        All  $39,250   $35,777          4.6        8.0         217
# 215        All  $72,250   $65,807          4.4        8.0         282
# 114       Rear  $81,795   $74,451          8.3       10.0         500
# 166        All  $49,995   $45,815          6.0        8.0         316
# 118        All  $41,475   $36,494          6.8       10.0         310
#
#      MPG_City  MPG_Highway  Weight  Wheelbase  Length
# 150        60           66    1850         95     155
# 373        59           51    2890        106     175
# 149        46           51    2732        103     175
# 404        38           46    3003         99     172
# 155        36           44    2500        103     175
# ..        ...          ...     ...        ...     ...
# 216        12           16    4576        100     185
# 215        12           16    5379        113     195
# 114        12           20    3410         99     176
# 166        10           12    6400        123     190
# 118        10           13    7190        137     227
#
# [427 rows x 15 columns]

# %%
df['Origin'].unique()
# Out:
# array(['Asia', 'Europe', 'USA'], dtype=object)

# %%
def origin_to_num(x):
    if x=='Asia': return 1
    if x=='Europe': return 2
    if x=='USA': return 3
df['Origin']=df['Origin'].apply(origin_to_num)
df
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV       1        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan       1      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan       1      Front  $26,990
# 3    Acura                   TL 4dr  Sedan       1      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan       1      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan       2      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan       2      Front  $45,210
# 426  Volvo                      V40  Wagon       2      Front  $26,135
# 427  Volvo                     XC70  Wagon       2        All  $35,145
# 428  Volvo                     XC70  Wagon       2        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 0    $33,337          3.5        6.0         265        17           23
# 1    $21,761          2.0        4.0         200        24           31
# 2    $24,647          2.4        4.0         200        22           29
# 3    $30,299          3.2        6.0         270        20           28
# 4    $39,014          3.5        6.0         225        18           24
# ..        ...         ...        ...         ...       ...          ...
# 424  $40,083          2.3        5.0         242        20           26
# 425  $42,573          2.9        6.0         268        19           26
# 426  $24,641          1.9        4.0         170        22           29
# 427  $33,112          2.5        5.0         208        20           27
# 428  $33,112          2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 0      4451        106     189
# 1      2778        101     172
# 2      3230        105     183
# 3      3575        108     186
# 4      3880        115     197
# ..      ...        ...     ...
# 424    3450        105     186
# 425    3653        110     190
# 426    2822        101     180
# 427    3823        109     186
# 428    3823        109     186
#
# [427 rows x 15 columns]

# %% [markdown]
# # Retrieving Data

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/cars.csv')
df.iloc[0]
# Out:
# Make              Acura
# Model               MDX
# Type                SUV
# Origin             Asia
# DriveTrain          All
# MSRP           $36,945
# Invoice        $33,337
# EngineSize          3.5
# Cylinders           6.0
# Horsepower          265
# MPG_City             17
# MPG_Highway          23
# Weight             4451
# Wheelbase           106
# Length              189
# Name: 0, dtype: object

# %%
df.iloc[-1]
# Out:
# Make              Volvo
# Model              XC70
# Type              Wagon
# Origin           Europe
# DriveTrain          All
# MSRP           $35,145
# Invoice        $33,112
# EngineSize          2.5
# Cylinders           5.0
# Horsepower          208
# MPG_City             20
# MPG_Highway          27
# Weight             3823
# Wheelbase           109
# Length              186
# Name: 428, dtype: object

# %%
df.iloc[0:5]
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
df.iloc[:,0]
# Out:
# 0      Acura
# 1      Acura
# 2      Acura
# 3      Acura
# 4      Acura
#        ...
# 424    Volvo
# 425    Volvo
# 426    Volvo
# 427    Volvo
# 428    Volvo
# Name: Make, Length: 429, dtype: object

# %%
df.iloc[:,0:5]
# Out:
#       Make                    Model   Type  Origin DriveTrain
# 0    Acura                      MDX    SUV    Asia        All
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front
# 2    Acura                  TSX 4dr  Sedan    Asia      Front
# 3    Acura                   TL 4dr  Sedan    Asia      Front
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front
# ..     ...                      ...    ...     ...        ...
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front
# 426  Volvo                      V40  Wagon  Europe      Front
# 427  Volvo                     XC70  Wagon  Europe        All
# 428  Volvo                     XC70  Wagon  Europe        All
#
# [429 rows x 5 columns]

# %%
df.iloc[[0,2,4],[1,3,5]]
# Out:
#         Model Origin      MSRP
# 0         MDX   Asia  $36,945
# 2     TSX 4dr   Asia  $26,990
# 4  3.5 RL 4dr   Asia  $43,755

# %%
df.iloc[0:5,8]
# Out:
# 0    6.0
# 1    4.0
# 2    4.0
# 3    6.0
# 4    6.0
# Name: Cylinders, dtype: float64

# %%
df.loc[0:5,'MPG_City']
# Out:
# 0    17
# 1    24
# 2    22
# 3    20
# 4    18
# 5    18
# Name: MPG_City, dtype: int64

# %%
df1=df[['EngineSize','Cylinders','Horsepower','MPG_City','MPG_Highway','Weight','Wheelbase','Length']]
df1=df.select_dtypes(include=['float64','int64'])
df1
# Out:
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0           3.5        6.0         265        17           23    4451
# 1           2.0        4.0         200        24           31    2778
# 2           2.4        4.0         200        22           29    3230
# 3           3.2        6.0         270        20           28    3575
# 4           3.5        6.0         225        18           24    3880
# ..          ...        ...         ...       ...          ...     ...
# 424         2.3        5.0         242        20           26    3450
# 425         2.9        6.0         268        19           26    3653
# 426         1.9        4.0         170        22           29    2822
# 427         2.5        5.0         208        20           27    3823
# 428         2.5        5.0         208        20           27    3823
#
#      Wheelbase  Length
# 0          106     189
# 1          101     172
# 2          105     183
# 3          108     186
# 4          115     197
# ..         ...     ...
# 424        105     186
# 425        110     190
# 426        101     180
# 427        109     186
# 428        109     186
#
# [429 rows x 8 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   EngineSize   429 non-null    float64
#  1   Cylinders    427 non-null    float64
#  2   Horsepower   429 non-null    int64
#  3   MPG_City     429 non-null    int64
#  4   MPG_Highway  429 non-null    int64
#  5   Weight       429 non-null    int64
#  6   Wheelbase    429 non-null    int64
#  7   Length       429 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 26.9 KB

# %% [markdown]
# # Getting Statistical Information

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/cars.csv')
df1.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway  \
# count  429.000000  427.000000  429.000000  429.000000   429.000000
# mean     3.195105    5.805621  215.867133   20.060606    26.843823
# std      1.107810    1.557103   71.753072    5.232095     5.734495
# min      1.300000    3.000000   73.000000   10.000000    12.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000
# 75%      3.900000    6.000000  255.000000   21.000000    29.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000
#
#             Weight   Wheelbase      Length
# count   429.000000  429.000000  429.000000
# mean   3578.524476  108.156177  186.361305
# std     758.188346    8.302198   14.341219
# min    1850.000000   89.000000  143.000000
# 25%    3105.000000  103.000000  178.000000
# 50%    3476.000000  107.000000  187.000000
# 75%    3977.000000  112.000000  194.000000
# max    7190.000000  144.000000  238.000000

# %%
df1.corr(method='pearson')
# Out:
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.908058    0.787222 -0.709127    -0.717010
# Cylinders      0.908058   1.000000    0.810207 -0.684170    -0.675917
# Horsepower     0.787222   0.810207    1.000000 -0.676687    -0.647193
# MPG_City      -0.709127  -0.684170   -0.676687  1.000000     0.941019
# MPG_Highway   -0.717010  -0.675917   -0.647193  0.941019     1.000000
# Weight         0.806922   0.741498    0.630627 -0.737885    -0.790872
# Wheelbase      0.636066   0.546430    0.387362 -0.507280    -0.524647
# Length         0.637191   0.547645    0.381555 -0.501525    -0.466093
#
#                Weight  Wheelbase    Length
# EngineSize   0.806922   0.636066  0.637191
# Cylinders    0.741498   0.546430  0.547645
# Horsepower   0.630627   0.387362  0.381555
# MPG_City    -0.737885  -0.507280 -0.501525
# MPG_Highway -0.790872  -0.524647 -0.466093
# Weight       1.000000   0.760678  0.689917
# Wheelbase    0.760678   1.000000  0.889177
# Length       0.689917   0.889177  1.000000

# %%
df1.corr(method='pearson')['MPG_City']
# Out:
# EngineSize    -0.709127
# Cylinders     -0.684170
# Horsepower    -0.676687
# MPG_City       1.000000
# MPG_Highway    0.941019
# Weight        -0.737885
# Wheelbase     -0.507280
# Length        -0.501525
# Name: MPG_City, dtype: float64

# %% [markdown]
# # Drawing Graphs/Plots

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/cars.csv')
sns.displot(data=df,x='MPG_City',bins=10,kde=True,color='red')
plt.show()

# %%
sns.regplot(x='Length',y='MPG_City',data=df,color='green')
plt.show()

# %%
df['Type'].unique()
# Out:
# array(['SUV', 'Sedan', 'Sports', 'Wagon', 'Truck', 'Hybrid'], dtype=object)

# %%
len(df['Type'].unique())
# Out:
# 6

# %%
box1=sns.boxplot(x='Type',y='MPG_City',data=df)
plt.show()

# %%
box2=sns.boxplot(x='Origin',y='MPG_City',data=df)
plt.show()

# %%
sns.pairplot(df,hue='Origin')
plt.show()

# %% [markdown]
# # Titanic Data

# %% [markdown]
# # Knowing Initial Details about Data

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# # Modifying or Removing Unwanted Data

# %%
df=pd.read_csv('G:/dataset/MLbookdataset/ML/Ml/17. EDA/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df[df['Survived']==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
#
# [342 rows x 12 columns]

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
len(df[df['Survived']==0])
# Out:
# 549

# %%
df1=df[df['Survived']==1]
df2=df[df['Survived']==0]

# %%
df3=df['Age'].dropna()
df3
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df[['Name','Age']][df['Survived']==1]
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  14.0
# ..                                                 ...   ...
# 875                   Najib, Miss. Adele Kiamie "Jane"  15.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  25.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 889                              Behr, Mr. Karl Howell  26.0
#
# [342 rows x 2 columns]

# %%
df3=df.select_dtypes(include=['float64','int64'])
df3
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.displot(data=df,x='Age',bins=10,kde=True,color='red')
plt.show()

# %%
sns.countplot(data=df1,x=df1['Sex'])
plt.show()

# %%
sns.countplot(data=df1,x=df1['Pclass'])
plt.show()
