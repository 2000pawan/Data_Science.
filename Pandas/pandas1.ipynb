# %%
import pandas as pd

# %%
df=pd.DataFrame([[101,2000,'sonu'],[102,3000,'monu']])

# %%
df
# Out:
#      0     1     2
# 0  101  2000  sonu
# 1  102  3000  monu

# %%
df=pd.DataFrame([[101,2000,'sonu'],[102,3000,'monu']],columns=['eid','sal','name'])
df
# Out:
#    eid   sal  name
# 0  101  2000  sonu
# 1  102  3000  monu

# %%
df=pd.DataFrame([[101,2000,'sonu'],[102,3000,'monu']],columns=['eid','sal','name'],index=[1,2])
df
# Out:
#    eid   sal  name
# 1  101  2000  sonu
# 2  102  3000  monu

# %%
df=pd.DataFrame({'eid':[101,102,103],'sal':[1000,1500,1200]})
df
# Out:
#    eid   sal
# 0  101  1000
# 1  102  1500
# 2  103  1200

# %%
pip install xlrd

# %%
pd.read_excel("G:/DS & ML/dataset/analysis/movies_sheets.xls")
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel("g:/dataset/analysis/movies_sheets.xls",sheet_name='2000s')
df
# Out:
#                                   Title  Year  \
# 0                       102 Dalmatians   2000
# 1                              28 Days   2000
# 2                            3 Strikes   2000
# 3                             Aberdeen   2000
# 4                All the Pretty Horses   2000
# ...                                 ...   ...
# 2095          X-Men Origins: Wolverine   2009
# 2096                          Year One   2009
# 2097                   Youth in Revolt   2009
# 2098  ZMD: Zombies of Mass Destruction   2009
# 2099                        Zombieland   2009
#
#                                       Category Language Country  \
# 0                      Adventure|Comedy|Family  English     USA
# 1                                 Comedy|Drama  English     USA
# 2                                       Comedy  English     USA
# 3                                        Drama  English      UK
# 4                        Drama|Romance|Western  English     USA
# ...

# %%
df=pd.read_excel("g:/dataset/analysis/movies_sheets.xls",sheet_name='2010s')
df
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                        Category  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %%
pd.read_excel('g:/dataset/analysis/players.xlsx',header=None,names=['roll','age','name'])
# Out:
#       roll  age   name
# 0    virat   32  12000
# 1    rohit   30  11900
# 2  pandaya   27   5000

# %%
pd.read_excel('g:/dataset/analysis/players.xlsx',header=None,names=['roll','age','name'])
# Out:
#       roll  age   name
# 0    virat   32  12000
# 1    rohit   30  11900
# 2  pandaya   27   5000

# %%
dict_dfs=pd.read_excel('g:/dataset/analysis/players.xlsx',sheet_name=None)
dict_dfs
# Out:
# {'Sheet1':      virat  32  12000
#  0    rohit  30  11900
#  1  pandaya  27   5000,
#  'Sheet2': Empty DataFrame
#  Columns: []
#  Index: [],
#  'Sheet3': Empty DataFrame
#  Columns: [aaaa]
#  Index: []}

# %%
dict_dfs.keys()
# Out:
# dict_keys(['Sheet1', 'Sheet2', 'Sheet3'])

# %%
df1=dict_dfs['Sheet1']
df1
# Out:
#      virat  32  12000
# 0    rohit  30  11900
# 1  pandaya  27   5000

# %%
df2=dict_dfs['Sheet3']
df2
# Out:
# Empty DataFrame
# Columns: [aaaa]
# Index: []

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls')
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',nrows=100)
df
# Out:
#                                                 Title  Year  \
# 0   Intolerance: Love's Struggle Throughout the Ages   1916
# 1                     Over the Hill to the Poorhouse   1920
# 2                                     The Big Parade   1925
# 3                                         Metropolis   1927
# 4                                      Pandora's Box   1929
# ..                                                ...   ...
# 95                   It's a Mad, Mad, Mad, Mad World   1963
# 96                                  The Great Escape   1963
# 97                                         Tom Jones   1963
# 98                              A Fistful of Dollars   1964
# 99                                A Hard Day's Night   1964
#
#                                 Category Language  Country Content Rating  \
# 0                      Drama|History|War      NaN      USA      Not Rated
# 1                            Crime|Drama      NaN      USA            NaN
# ...

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',nrows=100,skiprows=5)
df
# Out:
#                                        Pandora's Box   1929  \
# 0                                The Broadway Melody   1929
# 1                                      Hell's Angels   1930
# 2                                 A Farewell to Arms   1932
# 3                                        42nd Street   1933
# 4                                 She Done Him Wrong   1933
# ..                                                ...   ...
# 95  Dr. Strangelove or: How I Learned to Stop Worr...  1964
# 96                                        Goldfinger   1964
# 97                                      Mary Poppins   1964
# 98                                      My Fair Lady   1964
# 99                                 Nothing But a Man   1964
#
#                      Crime|Drama|Romance   German Germany  Not Rated  110  \
# 0                        Musical|Romance  English     USA     Passed  100
# 1                              Drama|War  English     USA     Passed   96
# ...

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',nrows=100,skiprows=[1,2,3,4,5])
df
# Out:
#                                                 Title  Year  \
# 0                                The Broadway Melody   1929
# 1                                      Hell's Angels   1930
# 2                                 A Farewell to Arms   1932
# 3                                        42nd Street   1933
# 4                                 She Done Him Wrong   1933
# ..                                                ...   ...
# 95  Dr. Strangelove or: How I Learned to Stop Worr...  1964
# 96                                        Goldfinger   1964
# 97                                      Mary Poppins   1964
# 98                                      My Fair Lady   1964
# 99                                 Nothing But a Man   1964
#
#                                 Category Language Country Content Rating  \
# 0                        Musical|Romance  English     USA         Passed
# 1                              Drama|War  English     USA         Passed
# ...

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',nrows=100,skiprows=(1,6))
df
# Out:
#                                                 Title  Year  \
# 0                     Over the Hill to the Poorhouse   1920
# 1                                     The Big Parade   1925
# 2                                         Metropolis   1927
# 3                                      Pandora's Box   1929
# 4                                      Hell's Angels   1930
# ..                                                ...   ...
# 94                                  The Great Escape   1963
# 95                                         Tom Jones   1963
# 96                              A Fistful of Dollars   1964
# 97                                A Hard Day's Night   1964
# 98  Dr. Strangelove or: How I Learned to Stop Worr...  1964
#
#                                 Category Language  Country Content Rating  \
# 0                            Crime|Drama      NaN      USA            NaN
# 1                      Drama|Romance|War      NaN      USA      Not Rated
# ...

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',usecols=['Title','Year','Duration'])
df
# Out:
#                                                   Title  Year  Duration
# 0     Intolerance: Love's Struggle Throughout the Ages   1916       123
# 1                       Over the Hill to the Poorhouse   1920       110
# 2                                       The Big Parade   1925       151
# 3                                           Metropolis   1927       145
# 4                                        Pandora's Box   1929       110
# ...                                                 ...   ...       ...
# 1333                                  Twin Falls Idaho   1999       111
# 1334                     Universal Soldier: The Return   1999        83
# 1335                                     Varsity Blues   1999       106
# 1336                                    Wild Wild West   1999       106
# 1337                                    Wing Commander   1999       100
#
# [1338 rows x 3 columns]

# %%
df=pd.read_excel('g:/dataset/analysis/movies_sheets.xls',usecols='A,E')
df
# Out:
#                                                   Title  Country
# 0     Intolerance: Love's Struggle Throughout the Ages       USA
# 1                       Over the Hill to the Poorhouse       USA
# 2                                       The Big Parade       USA
# 3                                           Metropolis   Germany
# 4                                        Pandora's Box   Germany
# ...                                                 ...      ...
# 1333                                  Twin Falls Idaho       USA
# 1334                     Universal Soldier: The Return       USA
# 1335                                     Varsity Blues       USA
# 1336                                    Wild Wild West       USA
# 1337                                    Wing Commander       USA
#
# [1338 rows x 2 columns]
