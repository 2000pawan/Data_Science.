# %%
import pandas as pd

# %%
df=pd.read_csv('world_alcohol.csv')

# %%
df.head()
# Out:
#    Year       WHO region                Country Beverage Types  Display Value
# 0  1986  Western Pacific               Viet Nam           Wine           0.00
# 1  1986         Americas                Uruguay          Other           0.50
# 2  1985           Africa           Cte d'Ivoire           Wine           1.62
# 3  1986         Americas               Colombia           Beer           4.27
# 4  1987         Americas  Saint Kitts and Nevis           Beer           1.98

# %%
print('Shape:-',df.shape)
print('Rows:-',df.shape[0])
print('Columns:-',df.shape[1])
print('Columns names:-',df.columns)
# Out:
# Shape:- (100, 5)
# Rows:- 100
# Columns:- 5
# Columns names:- Index(['Year', 'WHO region', 'Country', 'Beverage Types', 'Display Value'], dtype='object')

# %%
print(df.iloc[:2,:])
print('-------------------------------------------------')
print(df.iloc[:,:2].head())
print(df[['Display Value', 'Year']])
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0
# 1  1986         Americas   Uruguay          Other            0.5
# -------------------------------------------------
#    Year       WHO region
# 0  1986  Western Pacific
# 1  1986         Americas
# 2  1985           Africa
# 3  1986         Americas
# 4  1987         Americas
#     Display Value  Year
# 0            0.00  1986
# 1            0.50  1986
# 2            1.62  1985
# 3            4.27  1986
# 4            1.98  1987
# ..            ...   ...
# 95           0.00  1984
# 96           7.38  1985
# 97           0.00  1984
# 98           0.00  1984
# 99           0.00  1985
#
# [100 rows x 2 columns]

# %%
print(df.sample(5))
print('--------------------------------------------------')
print(df.sample(frac=0.02))
# Out:
#     Year WHO region     Country Beverage Types  Display Value
# 29  1986     Europe       Italy          Other            NaN
# 16  1984   Americas  Costa Rica           Wine           0.06
# 76  1985     Africa     Comoros           Beer           0.02
# 90  1989     Africa      Malawi           Wine           0.01
# 47  1986   Americas      Mexico          Other           0.04
# --------------------------------------------------
#     Year WHO region   Country Beverage Types  Display Value
# 19  1984     Africa     Kenya           Beer           1.08
# 55  1989   Americas  Suriname           Wine           0.04

# %%
print(df.isnull().sum())
print(df.dropna(inplace=True))
print(df.isnull().sum())
# Out:
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     5
# dtype: int64
# None
# Year              0
# WHO region        0
# Country           0
# Beverage Types    0
# Display Value     0
# dtype: int64

# %%
df2=df.drop_duplicates(subset=['WHO region'])
df2.shape
# Out:
# (6, 5)

# %%
print(df[df['Year']==1985].head())
print(df[df['Year']==1989].head())
# Out:
#     Year       WHO region                                            Country  \
# 2   1985           Africa                                       Cte d'Ivoire
# 7   1985           Africa                                             Angola
# 12  1985  Western Pacific                   Lao People's Democratic Republic
# 14  1985  Western Pacific                                           Viet Nam
# 26  1985           Europe  United Kingdom of Great Britain and Northern I...
#
#    Beverage Types  Display Value
# 2            Wine           1.62
# 7         Spirits           0.39
# 12           Beer           0.00
# 14        Spirits           0.05
# 26           Wine           1.36
#     Year WHO region     Country Beverage Types  Display Value
# 11  1989   Americas   Guatemala           Beer           0.62
# 17  1989     Africa  Seychelles           Beer           2.23
# 21  1989   Americas  Costa Rica        Spirits           4.51
# ...

# %%
print((df[(df['Year']==1987) | (df['Year']==1989)]).head(10))
# Out:
#     Year       WHO region                Country Beverage Types  Display Value
# 4   1987         Americas  Saint Kitts and Nevis           Beer           1.98
# 5   1987         Americas              Guatemala          Other           0.00
# 6   1987           Africa              Mauritius           Wine           0.13
# 10  1987           Africa               Botswana           Wine           0.20
# 11  1989         Americas              Guatemala           Beer           0.62
# 15  1987           Africa          Guinea-Bissau           Wine           0.07
# 17  1989           Africa             Seychelles           Beer           2.23
# 21  1989         Americas             Costa Rica        Spirits           4.51
# 28  1987  Western Pacific               Viet Nam           Beer           0.11
# 32  1989           Africa              Mauritius           Beer           1.60

# %%
(df[(df['Year']==1989) & (df['WHO region']=='Americas')]).head()
# Out:
#     Year WHO region                           Country Beverage Types  \
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 78  1989   Americas                           Jamaica          Other
#
#     Display Value
# 11           0.62
# 21           4.51
# 55           0.04
# 64           1.26
# 78           0.00

# %%
df[(df['Year']==1986) & ((df['WHO region']=='Western Pacific') & (df['Country']=='Viet Nam' ))]
# Out:
#    Year       WHO region   Country Beverage Types  Display Value
# 0  1986  Western Pacific  Viet Nam           Wine            0.0

# %%
df[((df['Year']==1986) | (df['Year']==1989)) &  (df['WHO region']=='Americas')]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 47  1986   Americas                            Mexico          Other
# 55  1989   Americas                          Suriname           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989   Americas                           Jamaica          Other
# 86  1986   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 47           0.04
# ...

# %%
df[((df['Year']==1986) | (df['Year']==1989)) &  ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))]
# Out:
#     Year WHO region                           Country Beverage Types  \
# 1   1986   Americas                           Uruguay          Other
# 3   1986   Americas                          Colombia           Beer
# 8   1986   Americas               Antigua and Barbuda        Spirits
# 11  1989   Americas                         Guatemala           Beer
# 21  1989   Americas                        Costa Rica        Spirits
# 34  1986     Europe                Russian Federation           Wine
# 37  1986     Europe                            Sweden           Beer
# 41  1986     Europe                    Czech Republic           Beer
# 47  1986   Americas                            Mexico          Other
# 49  1986     Europe                             Malta           Wine
# 55  1989   Americas                          Suriname           Wine
# 57  1989     Europe                           Croatia           Wine
# 64  1989   Americas  Bolivia (Plurinational State of)           Beer
# ...

# %%
df[((df['Year']==1986) | (df['Year']==1989)) &  ((df['WHO region']=='Americas') | (df['WHO region']=='Europe'))][['WHO region','Country','Beverage Types']].head(10)
# Out:
#    WHO region              Country Beverage Types
# 1    Americas              Uruguay          Other
# 3    Americas             Colombia           Beer
# 8    Americas  Antigua and Barbuda        Spirits
# 11   Americas            Guatemala           Beer
# 21   Americas           Costa Rica        Spirits
# 34     Europe   Russian Federation           Wine
# 37     Europe               Sweden           Beer
# 41     Europe       Czech Republic           Beer
# 47   Americas               Mexico          Other
# 49     Europe                Malta           Wine

# %%
df[(df['Display Value']>=5) & (df['Beverage Types']=='Beer')].head(10)
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %%
df[(df['Display Value']>=4) & ((df['Beverage Types']=='Beer') | (df['Beverage Types']=='Wine') | (df['Beverage Types']=='Spirits'))].head(10)
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 3   1986   Americas        Colombia           Beer           4.27
# 21  1989   Americas      Costa Rica        Spirits           4.51
# 41  1986     Europe  Czech Republic           Beer           6.82
# 57  1989     Europe         Croatia           Wine           5.10
# 91  1989     Europe        Bulgaria           Beer           4.43
# 96  1985     Europe      Luxembourg           Wine           7.38

# %%
df.loc[0:4,['WHO region','Beverage Types']]
# Out:
#         WHO region Beverage Types
# 0  Western Pacific           Wine
# 1         Americas          Other
# 2           Africa           Wine
# 3         Americas           Beer
# 4         Americas           Beer

# %%
df2=df.dropna()
df2[df2['WHO region'].str.contains('Ea')]
# Out:
#     Year             WHO region                                Country  \
# 13  1984  Eastern Mediterranean                            Afghanistan
# 20  1986        South-East Asia                                Myanmar
# 25  1984  Eastern Mediterranean                                Tunisia
# 27  1984  Eastern Mediterranean                                Bahrain
# 36  1987  Eastern Mediterranean                                  Egypt
# 38  1987  Eastern Mediterranean                                  Qatar
# 52  1986  Eastern Mediterranean                           Saudi Arabia
# 53  1984  Eastern Mediterranean                                 Kuwait
# 58  1984  Eastern Mediterranean                                Somalia
# 59  1989  Eastern Mediterranean                   Syrian Arab Republic
# 60  1987  Eastern Mediterranean             Iran (Islamic Republic of)
# 63  1985  Eastern Mediterranean                                  Libya
# ...

# %%
df3= ~ df['WHO region'].isin(['Africa','Eastern Mediterranean','Europe'])
df[df3]
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# ...

# %%
df[(df['Display Value'] <2.5) & (df['Display Value']>.5)].head()
# Out:
#     Year WHO region                Country Beverage Types  Display Value
# 2   1985     Africa           Cte d'Ivoire           Wine           1.62
# 4   1987   Americas  Saint Kitts and Nevis           Beer           1.98
# 8   1986   Americas    Antigua and Barbuda        Spirits           1.55
# 11  1989   Americas              Guatemala           Beer           0.62
# 17  1989     Africa             Seychelles           Beer           2.23

# %%
df[(df['Beverage Types']=='Wine') & (df['Display Value'] >.2)].count()
# Out:
# Year              9
# WHO region        9
# Country           9
# Beverage Types    9
# Display Value     9
# dtype: int64

# %%
df=pd.read_csv('world_alcohol.csv')
df.iloc[0::10,:]
df.filter(regex='0$', axis=0)
# Out:
#     Year             WHO region                     Country Beverage Types  \
# 0   1986        Western Pacific                    Viet Nam           Wine
# 10  1987                 Africa                    Botswana           Wine
# 20  1986        South-East Asia                     Myanmar           Wine
# 30  1986                 Africa                Sierra Leone          Other
# 40  1987                 Europe                     Austria        Spirits
# 50  1985                 Europe                 Switzerland          Other
# 60  1987  Eastern Mediterranean  Iran (Islamic Republic of)          Other
# 70  1986                 Africa                  Madagascar        Spirits
# 80  1985                 Africa                      Malawi          Other
# 90  1989                 Africa                      Malawi           Wine
#
#     Display Value
# 0            0.00
# 10           0.20
# 20           0.00
# 30           4.48
# 40           1.90
# 50           0.30
# ...

# %%
df.loc[:,'Country':'Display Value']
# Out:
#                                   Country Beverage Types  Display Value
# 0                                Viet Nam           Wine           0.00
# 1                                 Uruguay          Other           0.50
# 2                            Cte d'Ivoire           Wine           1.62
# 3                                Colombia           Beer           4.27
# 4                   Saint Kitts and Nevis           Beer           1.98
# ..                                    ...            ...            ...
# 95                                  Niger          Other           0.00
# 96                             Luxembourg           Wine           7.38
# 97                              Indonesia           Wine           0.00
# 98                      Equatorial Guinea           Wine           0.00
# 99  Democratic People's Republic of Korea           Wine           0.00
#
# [100 rows x 3 columns]

# %%
df.iloc[:,2:5]
# Out:
#                                   Country Beverage Types  Display Value
# 0                                Viet Nam           Wine           0.00
# 1                                 Uruguay          Other           0.50
# 2                            Cte d'Ivoire           Wine           1.62
# 3                                Colombia           Beer           4.27
# 4                   Saint Kitts and Nevis           Beer           1.98
# ..                                    ...            ...            ...
# 95                                  Niger          Other           0.00
# 96                             Luxembourg           Wine           7.38
# 97                              Indonesia           Wine           0.00
# 98                      Equatorial Guinea           Wine           0.00
# 99  Democratic People's Republic of Korea           Wine           0.00
#
# [100 rows x 3 columns]

# %%
df.loc[0:9,['Year','Country','Display Value']]
# Out:
#    Year                Country  Display Value
# 0  1986               Viet Nam           0.00
# 1  1986                Uruguay           0.50
# 2  1985           Cte d'Ivoire           1.62
# 3  1986               Colombia           4.27
# 4  1987  Saint Kitts and Nevis           1.98
# 5  1987              Guatemala           0.00
# 6  1987              Mauritius           0.13
# 7  1985                 Angola           0.39
# 8  1986    Antigua and Barbuda           1.55
# 9  1984                Nigeria           6.10

# %%
df.columns=['year','who region','country','beverage type','display values']
print(df.head())
# Out:
#    year       who region                country beverage type  display values
# 0  1986  Western Pacific               Viet Nam          Wine            0.00
# 1  1986         Americas                Uruguay         Other            0.50
# 2  1985           Africa           Cte d'Ivoire          Wine            1.62
# 3  1986         Americas               Colombia          Beer            4.27
# 4  1987         Americas  Saint Kitts and Nevis          Beer            1.98

# %%
df.rename(columns={'who region':'Who region','country':'Country'},inplace=True)
df.head()
# Out:
#    year       Who region                Country beverage type  display values
# 0  1986  Western Pacific               Viet Nam          Wine            0.00
# 1  1986         Americas                Uruguay         Other            0.50
# 2  1985           Africa           Cte d'Ivoire          Wine            1.62
# 3  1986         Americas               Colombia          Beer            4.27
# 4  1987         Americas  Saint Kitts and Nevis          Beer            1.98

# %%
df.loc[:,df.all()]
# Out:
#     year       Who region                                Country beverage type
# 0   1986  Western Pacific                               Viet Nam          Wine
# 1   1986         Americas                                Uruguay         Other
# 2   1985           Africa                           Cte d'Ivoire          Wine
# 3   1986         Americas                               Colombia          Beer
# 4   1987         Americas                  Saint Kitts and Nevis          Beer
# ..   ...              ...                                    ...           ...
# 95  1984           Africa                                  Niger         Other
# 96  1985           Europe                             Luxembourg          Wine
# 97  1984  South-East Asia                              Indonesia          Wine
# 98  1984           Africa                      Equatorial Guinea          Wine
# 99  1985  South-East Asia  Democratic People's Republic of Korea          Wine
#
# [100 rows x 4 columns]

# %%
df.loc[:,df.any()]
# Out:
#     year       Who region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    beverage type  display values
# 0           Wine            0.00
# 1          Other            0.50
# 2           Wine            1.62
# 3           Beer            4.27
# ...

# %%
df.loc[:,df.notnull().all()]
# Out:
#     year       Who region                                Country beverage type
# 0   1986  Western Pacific                               Viet Nam          Wine
# 1   1986         Americas                                Uruguay         Other
# 2   1985           Africa                           Cte d'Ivoire          Wine
# 3   1986         Americas                               Colombia          Beer
# 4   1987         Americas                  Saint Kitts and Nevis          Beer
# ..   ...              ...                                    ...           ...
# 95  1984           Africa                                  Niger         Other
# 96  1985           Europe                             Luxembourg          Wine
# 97  1984  South-East Asia                              Indonesia          Wine
# 98  1984           Africa                      Equatorial Guinea          Wine
# 99  1985  South-East Asia  Democratic People's Republic of Korea          Wine
#
# [100 rows x 4 columns]

# %%
df.loc[:,df.isnull().any()]
# Out:
#     display values
# 0             0.00
# 1             0.50
# 2             1.62
# 3             4.27
# 4             1.98
# ..             ...
# 95            0.00
# 96            7.38
# 97            0.00
# 98            0.00
# 99            0.00
#
# [100 rows x 1 columns]

# %%
df.dropna(how='any')
# Out:
#     year       Who region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    beverage type  display values
# 0           Wine            0.00
# 1          Other            0.50
# 2           Wine            1.62
# 3           Beer            4.27
# ...

# %%
df=pd.read_csv('world_alcohol.csv')
df.loc[:,'Year'::2]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [100 rows x 3 columns]

# %%
df.iloc[:,0::2]
# Out:
#     Year                                Country  Display Value
# 0   1986                               Viet Nam           0.00
# 1   1986                                Uruguay           0.50
# 2   1985                           Cte d'Ivoire           1.62
# 3   1986                               Colombia           4.27
# 4   1987                  Saint Kitts and Nevis           1.98
# ..   ...                                    ...            ...
# 95  1984                                  Niger           0.00
# 96  1985                             Luxembourg           7.38
# 97  1984                              Indonesia           0.00
# 98  1984                      Equatorial Guinea           0.00
# 99  1985  Democratic People's Republic of Korea           0.00
#
# [100 rows x 3 columns]

# %%
df.iloc[1::5]
# Out:
#     Year             WHO region  \
# 1   1986               Americas
# 6   1987                 Africa
# 11  1989               Americas
# 16  1984               Americas
# 21  1989               Americas
# 26  1985                 Europe
# 31  1986        Western Pacific
# 36  1987  Eastern Mediterranean
# 41  1986                 Europe
# 46  1987               Americas
# 51  1987                 Europe
# 56  1987        Western Pacific
# 61  1984        Western Pacific
# 66  1987  Eastern Mediterranean
# 71  1985                 Africa
# 76  1985                 Africa
# 81  1985                 Europe
# 86  1986               Americas
# 91  1989                 Europe
# 96  1985                 Europe
#
#                                               Country Beverage Types  \
# 1                                             Uruguay          Other
# 6                                           Mauritius           Wine
# ...
