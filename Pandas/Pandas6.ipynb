# %%
import pandas as pd

# %%
df=pd.read_csv('g:/dataset/analysis/weather_data.txt')

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
 df.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.temperature.mean()
# Out:
# 32.666666666666664

# %%
df.windspeed.mean()
# Out:
# 8.666666666666666

# %%
df.event.mode()
# Out:
# 0    Sunny
# Name: event, dtype: object

# %%
df.fillna({'temperature':32,'windspeed':9,'event':'Sunny'})
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        9.0    Snow
# 3   1/6/2017         32.0        7.0   Sunny
# 4   1/7/2017         32.0        9.0    Rain
# 5   1/8/2017         32.0        9.0   Sunny
# 6   1/9/2017         32.0        9.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.ffill()
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        9.0    Snow
# 3   1/6/2017         28.0        7.0    Snow
# 4   1/7/2017         32.0        7.0    Rain
# 5   1/8/2017         32.0        7.0   Sunny
# 6   1/9/2017         32.0        7.0   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df['temperature']=df.temperature.ffill()
df['windspeed']=df.windspeed.bfill()

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         28.0        7.0     NaN
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         32.0        8.0   Sunny
# 6   1/9/2017         32.0        8.0     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.at[3,'event']='Sunny'

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         28.0        7.0   Sunny
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         32.0        8.0   Sunny
# 6   1/9/2017         32.0        8.0     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017         32.0        9.0   Sunny
# 2   1/5/2017         28.0        7.0    Snow
# 3   1/6/2017         28.0        7.0   Sunny
# 4   1/7/2017         32.0        8.0    Rain
# 5   1/8/2017         32.0        8.0   Sunny
# 6   1/9/2017         32.0        8.0     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df=pd.read_csv('g:/dataset/analysis/weather_data.txt')

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=0)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=0,thresh=3)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=0,thresh=3).shape
# Out:
# (7, 4)

# %%
df.dropna(axis=0,thresh=2)
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=0,thresh=2).shape
# Out:
# (9, 4)

# %%
df.dropna(axis=0,subset=['temperature'])
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 2   1/5/2017         28.0        NaN    Snow
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=0,subset=['temperature','windspeed'])
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.dropna(axis=1)
# Out:
#          day
# 0   1/1/2017
# 1   1/4/2017
# 2   1/5/2017
# 3   1/6/2017
# 4   1/7/2017
# 5   1/8/2017
# 6   1/9/2017
# 7  1/10/2017
# 8  1/11/2017
# 9  1/12/2017

# %%
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.drop('event',axis=1)
# Out:
#          day  temperature  windspeed
# 0   1/1/2017         32.0        6.0
# 1   1/4/2017          NaN        9.0
# 2   1/5/2017         28.0        NaN
# 3   1/6/2017          NaN        7.0
# 4   1/7/2017         32.0        NaN
# 5   1/8/2017          NaN        NaN
# 6   1/9/2017          NaN        NaN
# 7  1/10/2017         34.0        8.0
# 8  1/11/2017         40.0       12.0
# 9  1/12/2017         30.0       10.0

# %%
df.drop(['event','day'],axis=1)
# Out:
#    temperature  windspeed
# 0         32.0        6.0
# 1          NaN        9.0
# 2         28.0        NaN
# 3          NaN        7.0
# 4         32.0        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7         34.0        8.0
# 8         40.0       12.0
# 9         30.0       10.0

# %%
df.drop([0,5,6],axis=0)
# Out:
#          day  temperature  windspeed   event
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df=pd.read_csv('g:/dataset/analysis/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=0,subset=['Age','gender','Pclass','Survived'],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df.Age<=10].shape
# Out:
# (64, 12)

# %%
df[df.Age>=60].shape
# Out:
# (26, 12)

# %%
df[(df.Age<=10)&(df.Survived==1)].shape
# Out:
# (38, 12)

# %%
df[(df.Age>=60)&(df.Survived==1)].shape
# Out:
# (7, 12)

# %%
df=pd.read_csv('g:/dataset/analysis/weather_data2.txt')
df
# Out:
#           day  temperature  windspeed     event
# 0    1/1/2017           32          6      Rain
# 1    1/4/2017       -99999          9     Sunny
# 2    1/5/2017           28     -99999      Snow
# 3    1/6/2017       -99999          7  No event
# 4    1/7/2017           32     -88888      Rain
# 5   1/11/2017           40         12  No event
# 6    1/1/2017           32          6      Rain
# 7    1/4/2017       -99999          9     Sunny
# 8    1/5/2017           28     -99999      Snow
# 9    1/6/2017       -99999          7  No event
# 10   1/7/2017           32     -88888      Rain
# 11  1/11/2017           40         12  No event
# 12   1/1/2017           32          6      Rain
# 13   1/4/2017       -99999          9     Sunny
# 14   1/5/2017           28     -99999      Snow
# 15   1/6/2017       -99999          7  No event
# 16   1/7/2017           32     -88888      Rain
# 17  1/11/2017           40         12  No event

# %%
df.drop_duplicates()
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017       -99999          9     Sunny
# 2   1/5/2017           28     -99999      Snow
# 3   1/6/2017       -99999          7  No event
# 4   1/7/2017           32     -88888      Rain
# 5  1/11/2017           40         12  No event

# %%
df.drop_duplicates(subset=['temperature'])
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017       -99999          9     Sunny
# 2   1/5/2017           28     -99999      Snow
# 5  1/11/2017           40         12  No event

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017       -99999          9     Sunny
# 2   1/5/2017           28     -99999      Snow
# 3   1/6/2017       -99999          7  No event
# 4   1/7/2017           32     -88888      Rain
# 5  1/11/2017           40         12  No event

# %%
df.replace({'temperature':-99999},30,inplace=True)
df.replace({'windspeed':[-99999,-88888]},10,inplace=True)

# %%
df
# Out:
#          day  temperature  windspeed     event
# 0   1/1/2017           32          6      Rain
# 1   1/4/2017           30          9     Sunny
# 2   1/5/2017           28         10      Snow
# 3   1/6/2017           30          7  No event
# 4   1/7/2017           32         10      Rain
# 5  1/11/2017           40         12  No event

# %%
df=pd.read_csv('g:/dataset/analysis/weather_data3.txt')

# %%
df
# Out:
#          day temperature windspeed   event
# 0   1/1/2017         32F      6mph    Rain
# 1   1/4/2017         NaN      9mph  Su@nny
# 2   1/5/2017         2_8       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017         32C       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny

# %%
df.replace({'temperature':'[^0-9]'},'',regex=True)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017          32      6mph    Rain
# 1   1/4/2017         NaN      9mph  Su@nny
# 2   1/5/2017          28       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017          32       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny

# %%
df
# Out:
#          day temperature windspeed   event
# 0   1/1/2017         32F      6mph    Rain
# 1   1/4/2017         NaN      9mph  Su@nny
# 2   1/5/2017         2_8       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017         32C       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny

# %%
df2=df.replace({'temperature':'[^0-9]'},'',regex=True)

# %%
df2
# Out:
#          day temperature windspeed   event
# 0   1/1/2017          32      6mph    Rain
# 1   1/4/2017         NaN      9mph  Su@nny
# 2   1/5/2017          28       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017          32       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny

# %%
df2.replace({'event':'[^A-Z,a-z]'},'',regex=True)
# Out:
#          day temperature windspeed   event
# 0   1/1/2017          32      6mph    Rain
# 1   1/4/2017         NaN      9mph   Sunny
# 2   1/5/2017          28       NaN    Snow
# 3   1/6/2017         NaN         7     NaN
# 4   1/7/2017          32       NaN    Rain
# 5   1/8/2017         NaN       NaN   Sunny
# 6   1/9/2017         NaN       NaN     NaN
# 7  1/10/2017          34         8  Cloudy
# 8  1/11/2017          40        12   Sunny
